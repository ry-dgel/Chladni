# %%
import matplotlib
import matplotlib.pyplot as p
import numpy as np
import spinmob as s
from scipy.interpolate import interp1d

# %%
amps = np.load('data/30_300_0.5.npy')/95.6
freq = np.linspace(30,300,len(amps))[20:300]
amps = amps[20:300]

# %%
cube = interp1d(freq,amps,kind='cubic')

# %%
p.figure()
p.plot(freq,amps,'.')
p.plot(np.linspace(np.min(freq),np.max(freq),len(freq)),np.ones(len(amps))*np.max(amps),'--')
p.plot(np.ones(50)*freq[126],np.linspace(0,0.38,50),'g--')
p.plot(np.ones(50)*freq[139],np.linspace(0,0.38,50),'g--')

interpf = np.linspace(np.min(freq),np.max(freq),10000)
interpa = cube(interpf)
p.plot(interpf,interpa)

p.show()

# %%
np.where(np.abs(interpa - np.max(amps)/2) <= 0.001)
# Out:
# (array([4531, 4532, 4949, 4950]),)

# %%
interpa[4532]
# Out:
# 0.18898293033930466

# %%
np.max(amps)/2
# Out:
# 0.18870292887029289

# %%
interpa[4949]
# Out:
# 0.18897183029792036

# %%
106/(interpf[4949] - interpf[4532])
# Out:
# 18.220159356385825
