# %% [markdown]
# This document is for the calculation of the parameter C.

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
filenames = ['data/13_102.5_104.5_0.1.npy',
             'data/15_216_220_0.2.npy',
             'data/17_1003_1009_0.2.npy',]
for data_filename in filenames: 
    amplitude = np.load(data_filename)
    summed_z = np.max(np.exp(amplitude), 2)
    plt.imshow(summed_z)
    plt.show()

# %%
frequencies = np.array([102.5, 216, 1005])
eigenvalues_squared = np.array([36.1, 73.7, 310.1])

# %%
frequencies/eigenvalues_squared
# Out:
# array([ 2.83933518,  2.93080054,  3.24089004])
