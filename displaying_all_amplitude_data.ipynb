# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
data_filenames = [
    '13_102.5_104.5_0.1.npy',
    '13_370_400_0.5.npy',
    '13_467_474_0.2.npy',
    '13_479_485_0.2.npy',
    '13_490_496_0.2.npy',
    '15_216_220_0.2.npy',
    '15_314.5_318.5_0.2.npy',
    '15_646_650_0.2.npy',
    '15_710_718_0.2.npy',
    '15_711_717_0.2.npy',
    '15_900_905_0.2.npy',
    '17_1003_1009_0.2.npy',
    '17_499_506_0.2.npy'
]
for data_filename in data_filenames:
    amplitude = np.load('data/'+data_filename)
    summed_z = np.sum(amplitude, 2)
    print(data_filename)
    plt.imshow(summed_z)
    plt.show()
# Out:
# 13_102.5_104.5_0.1.npy
# 13_370_400_0.5.npy
# 13_467_474_0.2.npy
# 13_479_485_0.2.npy
# 13_490_496_0.2.npy
# 15_216_220_0.2.npy
# 15_314.5_318.5_0.2.npy
# 15_646_650_0.2.npy
# 15_710_718_0.2.npy
# 15_711_717_0.2.npy
# 15_900_905_0.2.npy
# 17_1003_1009_0.2.npy
# 17_499_506_0.2.npy

# %%
similar_scans = [
    'data/15_710_718_0.2.npy',
    'data/15_711_717_0.2.npy']
similar_scan_datas = [np.load(similar_scan) for similar_scan in similar_scans]

# %%
similar_scan_datas[0].shape
# Out:
# (15, 15, 41)

# %%
print(np.arange(710, 718.0001, 0.2)[10])
print(np.arange(711, 717.0001, 0.2)[5])
# Out:
# 712.0
# 712.0

# %%
plt.imshow(similar_scan_datas[0][:,:,10]-similar_scan_datas[1][:,:,5])

# %%
np.mean(np.square(similar_scan_datas[0][:,:,10]-similar_scan_datas[1][:,:,5]))
# Out:
# 0.0079306666666666675
